# %% [markdown]
# 195026 \
# To \
# 2 BS ITE

# %%
#First problem


social_graph = {
    "@bongolpoc":{"first_name":"Joselito",
                  "last_name":"Olpoc",
                  "following":[
                  ]
    },
    "@joaquin":  {"first_name":"Joaquin",
                  "last_name":"Gonzales",
                  "following":[
                      "@chums","@jobenilagan"
                  ]
    },
    "@chums" : {"first_name":"Matthew",
                "last_name":"Uy",
                "following":[
                    "@bongolpoc","@miketan","@rudyang","@joeilagan"
                ]
    },
    "@jobenilagan":{"first_name":"Joben",
                   "last_name":"Ilagan",
                   "following":[
                    "@eeebeee","@joeilagan","@chums","@joaquin"
                   ]
    },
    "@joeilagan":{"first_name":"Joe",
                  "last_name":"Ilagan",
                  "following":[
                    "@eeebeee","@jobenilagan","@chums"
                  ]
    },
    "@eeebeee":  {"first_name":"Elizabeth",
                  "last_name":"Ilagan",
                  "following":[
                    "@jobenilagan","@joeilagan"
                  ]
    },
}


from_member = input("First user: ")
to_member = input("Second user: ")

def relationship_status(from_member,to_member):
    if from_member in social_graph[to_member]["following"] and to_member in social_graph[from_member]["following"]:
        return print("They're both friends.")
    elif to_member in social_graph[from_member]["following"]:
        return print(to_member, "is followed by", from_member)
    elif from_member in social_graph[to_member]["following"]:
        return print(to_member, "is a follower of", from_member)
    else: 
        return print("None")
    
status = relationship_status(from_member, to_member)

# %%
#Second Problem

board1 = [
['X','X','O'],
['O','X','O'],
['O','','X'],
]

board2 = [
['X','X','O'],
['O','X','O'],
['','O','X'],
]

board3 = [
['O','X','O'],
['','O','X'],
['X','X','O'],
]

board4 = [
['X','X','X'],
['O','X','O'],
['O','','O'],
]

board5 = [
['X','X','O'],
['O','X','O'],
['X','','O'],
]

board6 = [
['X','X','O'],
['O','X','O'],
['X','',''],
]

import numpy as np

def get_winner(board):
    def row_win(board):
        for row in board:
            if len(set(row)) == 1:
                return row [0]
        return "None"
    def diag_win(board):
        if len(set([board[i][i] for i in range(len(board))])) == 1:
            return board[0][0]
        if len(set([board[i][len(board)-i-1] for i in range(len(board))])) == 1:
            return board[0][len(board)-1]
        return "None"
    def test(board):
        for col_win in [board, np.transpose(board)]:
            result = row_win(col_win)
            if result: 
                return result
        return diag_win(board)
    return test(board)

print(get_winner(board4))
# Out:
# X

# %%
#Third problem

locations = {
    "admu":{
        "name":"Ateneo de Manila University",
        "latitude":14.6394557,
        "longitude":121.0758975        
    },
    "upd":{
        "name":"University of the Philippines-Diliman Campus",
        "latitude":14.6538519,
        "longitude":121.0663348
    },
    "dlsu":{
        "name":"De La Salle University-Taft",
        "latitude":14.5647346,
        "longitude":120.9909876

    }, # <-- Note that Python does not complain about this extra comma. This is perfectly okay.
       #     The creators of Python saw that dictionaries tend to be changed a lot, so allowing this is a
       #     convenience for developers who need to add elements when needed.
}

legs = {
     ("upd","admu"):{
         "travel_time_mins":10
     },
     ("admu","dlsu"):{
         "travel_time_mins":35
     },
     ("dlsu","upd"):{
         "travel_time_mins":55
     }
}

source = input("Enter source: ")
destination = input("Enter destination: ")

def eta(source, destination):
    if source == "upd" and destination == "admu":
        return legs ["upd","admu"]["travel_time_mins"]
    elif source == "admu" and destination == "dlsu":
        return legs ["admu","dlsu"]["travel_time_mins"]
    elif source == "dlsu" and destination == "upd":
        return legs["dlsu","upd"]["travel_time_mins"]
    elif source == "upd" and destination == "dlsu":
        return legs["upd","admu"]["travel_time_mins"] + legs["admu","dlsu"]["travel_time_mins"]
    elif source == "admu" and destination == "upd":
        return legs["admu","dlsu"]["travel_time_mins"] + legs["dlsu","upd"]["travel_time_mins"]
    elif source == "dlsu" and destination == "admu":
        return legs["dlsu","upd"]["travel_time_mins"] + legs["upd","admu"]["travel_time_mins"]
    else: 
        return "None" 

estimated_time = eta(source,destination)
print(estimated_time)
